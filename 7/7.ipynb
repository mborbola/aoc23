# %%
card_strengths = {
    "A": 14, "K": 13, "Q": 12, "J": 11, "T": 10, "9": 9, "8": 8, "7": 7, "6": 6, "5": 5, "4": 4, "3": 3, "2": 2
}

hand_type_strengths = {
    "FIVE_K": 7,
    "FOUR_K": 6,
    "FULL_HOUSE": 5,
    "THREE_K": 4,
    "TWO_P": 3,
    "ONE_P": 2,
    "HIGH_CARD": 1
}

def is_five_of_a_kind(cards):
    return cards.count(cards[0]) == 5

def is_four_of_a_kind(cards):
    return cards.count(cards[0]) == 4 or cards.count(cards[1]) == 4

def is_three_of_a_kind(cards):
    """On it's own it's not true! Should be used only after full house check"""
    return cards.count(cards[0]) == 3 or cards.count(cards[1]) == 3 or cards.count(cards[2]) == 3

def is_one_pair(cards):
    return cards.count(cards[0]) == 2 or cards.count(cards[1]) == 2 or cards.count(cards[2]) == 2 or cards.count(cards[3]) == 2

def is_full_house(cards):
    """Optimization tip: return the is_three_of_a_kind and is_one_pair results if not full house"""
    return is_three_of_a_kind(cards) and is_one_pair(cards)

def is_two_pairs(cards):
    cards = sorted(cards)
    not_same = cards[0] != cards[2] and cards[0] != cards[4] and cards[2] != cards[4]
    return not_same and cards.count(cards[1]) == 2 and cards.count(cards[3]) == 2

def get_hand_type(cards:str):
    if is_five_of_a_kind(cards):
        return 'FIVE_K'
    elif is_four_of_a_kind(cards):
        return 'FOUR_K'
    elif is_full_house(cards):
        return 'FULL_HOUSE'
    elif is_three_of_a_kind(cards):
        return 'THREE_K'
    elif is_two_pairs(cards):
        return 'TWO_P'
    elif is_one_pair(cards):
        return 'ONE_P'
    else:
        return 'HIGH_CARD'

print(get_hand_type('AAAAA'))
print(get_hand_type('AA8AA'))
print(get_hand_type('23332'))
print(get_hand_type('TTT98'))
print(get_hand_type('23432'))
print(get_hand_type('A23A4'))
print(get_hand_type('23456'))
# Out:
# FIVE_K
# FOUR_K
# FULL_HOUSE
# THREE_K
# TWO_P
# ONE_P
# HIGH_CARD

# %%
def line_to_hand(line: str):
    line.strip()
    cards, bid = line.split()
    return {"cards": cards, "bid": int(bid), "type": get_hand_type(cards)}

hands = []

with open('input.txt', 'r') as file:
    for line in file:
        hands.append(line_to_hand(line))
print(hands[0:5])
# Out:
# [{'cards': 'T6782', 'bid': 898, 'type': 'HIGH_CARD'}, {'cards': '26T7A', 'bid': 345, 'type': 'HIGH_CARD'}, {'cards': '56856', 'bid': 92, 'type': 'TWO_P'}, {'cards': '88J88', 'bid': 379, 'type': 'FOUR_K'}, {'cards': '8QQJ8', 'bid': 792, 'type': 'TWO_P'}]

# %%
import functools

def compare_two_hands(hand1, hand2):
    type_diff = hand_type_strengths[hand1["type"]] - hand_type_strengths[hand2["type"]]
    if type_diff == 0:
        for card_from_hand1, card_from_hand2 in zip(hand1["cards"], hand2["cards"]):
            card_diff = card_strengths[card_from_hand1] - card_strengths[card_from_hand2]
            if card_diff != 0:
                return card_diff
    return type_diff

hands.sort(key=functools.cmp_to_key(compare_two_hands))

print(hands)
# Out:
# [{'cards': '23Q7A', 'bid': 878, 'type': 'HIGH_CARD'}, {'cards': '25Q47', 'bid': 739, 'type': 'HIGH_CARD'}, {'cards': '26T7A', 'bid': 345, 'type': 'HIGH_CARD'}, {'cards': '27T34', 'bid': 134, 'type': 'HIGH_CARD'}, {'cards': '2897K', 'bid': 321, 'type': 'HIGH_CARD'}, {'cards': '2935K', 'bid': 543, 'type': 'HIGH_CARD'}, {'cards': '2T476', 'bid': 90, 'type': 'HIGH_CARD'}, {'cards': '2T6Q5', 'bid': 559, 'type': 'HIGH_CARD'}, {'cards': '2J4KA', 'bid': 43, 'type': 'HIGH_CARD'}, {'cards': '2J876', 'bid': 713, 'type': 'HIGH_CARD'}, {'cards': '2JT9K', 'bid': 136, 'type': 'HIGH_CARD'}, {'cards': '2Q695', 'bid': 273, 'type': 'HIGH_CARD'}, {'cards': '2Q93J', 'bid': 755, 'type': 'HIGH_CARD'}, {'cards': '2K597', 'bid': 742, 'type': 'HIGH_CARD'}, {'cards': '3298A', 'bid': 325, 'type': 'HIGH_CARD'}, {'cards': '32KJT', 'bid': 733, 'type': 'HIGH_CARD'}, {'cards': '3562T', 'bid': 877, 'type': 'HIGH_CARD'}, {'cards': '3769A', 'bid': 429, 'type': 'HIGH_CARD'}, {'cards': '37K2A', 'bid': 348, 'type': 'HIGH_CARD'}, {'cards': '37A25', 'bid': 300, 'type': 'HIGH_CARD'}, {'cards': '382QA', 'bid': 320, 'type': 'HIGH_CARD'}, {'cards': '39K28', 'bid': 665, 'type': 'HIGH_CARD'}, {'cards': '3T549', 'bid': 811, 'type': 'HIGH_CARD'}, {'cards': '3J698', 'bid': 837, 'type': 'HIGH_CARD'}, {'cards': '3QJAK', 'bid': 241, 'type': 'HIGH_CARD'}, {'cards': '3KJ75', 'bid': 547, 'type': 'HIGH_CARD'}, {'cards': '436J2', 'bid': 685, 'type': 'HIGH_CARD'}, {'cards': '456J8', 'bid': 15, 'type': 'HIGH_CARD'}, {'cards': '469T8', 'bid': 72, 'type': 'HIGH_CARD'}, {'cards': '4732A', 'bid': 420, 'type': 'HIGH_CARD'}, {'cards': '473Q6', 'bid': 988, 'type': 'HIGH_CARD'}, {'cards': '475K6', 'bid': 109, 'type': 'HIGH_CARD'}, {'cards': '4853Q', 'bid': 476, 'type': 'HIGH_CARD'}, {'cards': '4938T', 'bid': 156, 'type': 'HIGH_CARD'}, {'cards': '49586', 'bid': 515, 'type': 'HIGH_CARD'}, {'cards': '4T7A5', 'bid': 956, 'type': 'HIGH_CARD'}, {'cards': '4T9K6', 'bid': 997, 'type': 'HIGH_CARD'}, {'cards': '4J9K8', 'bid': 353, 'type': 'HIGH_CARD'}, {'cards': '4K586', 'bid': 760, 'type': 'HIGH_CARD'}, {'cards': '4K92J', 'bid': 33, 'type': 'HIGH_CARD'}, {'cards': '4A2T5', 'bid': 984, 'type': 'HIGH_CARD'}, {'cards': '4A638', 'bid': 880, 'type': 'HIGH_CARD'}, {'cards': '4AK87', 'bid': 78, 'type': 'HIGH_CARD'}, {'cards': '52T67', 'bid': 177, 'type': 'HIGH_CARD'}, {'cards': '53Q8K', 'bid': 257, 'type': 'HIGH_CARD'}, {'cards': '5637T', 'bid': 734, 'type': 'HIGH_CARD'}, {'cards': '57A9J', 'bid': 996, 'type': 'HIGH_CARD'}, {'cards': '57AQ4', 'bid': 671, 'type': 'HIGH_CARD'}, {'cards': '584JT', 'bid': 743, 'type': 'HIGH_CARD'}, {'cards': '58KA4', 'bid': 795, 'type': 'HIGH_CARD'}, {'cards': '592A6', 'bid': 449, 'type': 'HIGH_CARD'}, {'cards': '59873', 'bid': 555, 'type': 'HIGH_CARD'}, {'cards': '59J8A', 'bid': 692, 'type': 'HIGH_CARD'}, {'cards': '59Q7T', 'bid': 944, 'type': 'HIGH_CARD'}, {'cards': '5T9K4', 'bid': 780, 'type': 'HIGH_CARD'}, {'cards': '5TK47', 'bid': 395, 'type': 'HIGH_CARD'}, {'cards': '5JAT8', 'bid': 778, 'type': 'HIGH_CARD'}, {'cards': '5QT27', 'bid': 959, 'type': 'HIGH_CARD'}, {'cards': '5QT2J', 'bid': 854, 'type': 'HIGH_CARD'}, {'cards': '5QK4A', 'bid': 474, 'type': 'HIGH_CARD'}, {'cards': '5K6Q2', 'bid': 971, 'type': 'HIGH_CARD'}, {'cards': '5KJ74', 'bid': 866, 'type': 'HIGH_CARD'}, {'cards': '5A32J', 'bid': 943, 'type': 'HIGH_CARD'}, {'cards': '5A8JK', 'bid': 447, 'type': 'HIGH_CARD'}, {'cards': '5A9KQ', 'bid': 494, 'type': 'HIGH_CARD'}, {'cards': '627JK', 'bid': 894, 'type': 'HIGH_CARD'}, {'cards': '62J57', 'bid': 890, 'type': 'HIGH_CARD'}, {'cards': '6347A', 'bid': 497, 'type': 'HIGH_CARD'}, {'cards': '654A9', 'bid': 700, 'type': 'HIGH_CARD'}, {'cards': '687A5', 'bid': 528, 'type': 'HIGH_CARD'}, {'cards': '694T2', 'bid': 679, 'type': 'HIGH_CARD'}, {'cards': '6T789', 'bid': 167, 'type': 'HIGH_CARD'}, {'cards': '6J32T', 'bid': 380, 'type': 'HIGH_CARD'}, {'cards': '6JQ3A', 'bid': 459, 'type': 'HIGH_CARD'}, {'cards': '6JA9K', 'bid': 950, 'type': 'HIGH_CARD'}, {'cards': '6Q3JT', 'bid': 909, ...

# %%
sum = 0
for i in range(len(hands)):
    sum += (i+1) * hands[i]["bid"]

print(sum)
# Out:
# 247815719

# %% [markdown]
# # Part 2

# %%
updated_card_strengths = {
    "A": 14, "K": 13, "Q": 12, "T": 10, "9": 9, "8": 8, "7": 7, "6": 6, "5": 5, "4": 4, "3": 3, "2": 2, "J": 1
}

def replace_jokers(cards:str):
    max_card_count = 0
    max_card = 'J'
    for card in cards:
        if card != 'J':
            count = cards.count(card)
            if count > max_card_count:
                max_card_count = count
                max_card = card
    return cards.replace("J", max_card)
    
def updated_get_hand_type(cards:str):
    cards = replace_jokers(cards)
    if is_five_of_a_kind(cards):
        return 'FIVE_K'
    elif is_four_of_a_kind(cards):
        return 'FOUR_K'
    elif is_full_house(cards):
        return 'FULL_HOUSE'
    elif is_three_of_a_kind(cards):
        return 'THREE_K'
    elif is_two_pairs(cards):
        return 'TWO_P'
    elif is_one_pair(cards):
        return 'ONE_P'
    else:
        return 'HIGH_CARD'
    
def updated_line_to_hand(line: str):
    line.strip()
    cards, bid = line.split()
    return {"cards": cards, "bid": int(bid), "type": updated_get_hand_type(cards)}

print(updated_get_hand_type("32T3K"))
print(updated_get_hand_type("T55J5"))
print(updated_get_hand_type("KK677"))
print(updated_get_hand_type("KTJJT"))
print(updated_get_hand_type("QQQJA"))
# Out:
# ONE_P
# FOUR_K
# TWO_P
# FOUR_K
# FOUR_K

# %%
updated_hands = []

with open('input.txt', 'r') as file:
    for line in file:
        updated_hands.append(updated_line_to_hand(line))
print(updated_hands[0:5])
# Out:
# [{'cards': 'T6782', 'bid': 898, 'type': 'HIGH_CARD'}, {'cards': '26T7A', 'bid': 345, 'type': 'HIGH_CARD'}, {'cards': '56856', 'bid': 92, 'type': 'TWO_P'}, {'cards': '88J88', 'bid': 379, 'type': 'FIVE_K'}, {'cards': '8QQJ8', 'bid': 792, 'type': 'FULL_HOUSE'}]

# %%
def updated_compare_two_hands(hand1, hand2):
    type_diff = hand_type_strengths[hand1["type"]] - hand_type_strengths[hand2["type"]]
    if type_diff == 0:
        for card_from_hand1, card_from_hand2 in zip(hand1["cards"], hand2["cards"]):
            card_diff = updated_card_strengths[card_from_hand1] - updated_card_strengths[card_from_hand2]
            if card_diff != 0:
                return card_diff
    return type_diff

updated_hands.sort(key=functools.cmp_to_key(updated_compare_two_hands))

print(updated_hands)
# Out:
# [{'cards': '23Q7A', 'bid': 878, 'type': 'HIGH_CARD'}, {'cards': '25Q47', 'bid': 739, 'type': 'HIGH_CARD'}, {'cards': '26T7A', 'bid': 345, 'type': 'HIGH_CARD'}, {'cards': '27T34', 'bid': 134, 'type': 'HIGH_CARD'}, {'cards': '2897K', 'bid': 321, 'type': 'HIGH_CARD'}, {'cards': '2935K', 'bid': 543, 'type': 'HIGH_CARD'}, {'cards': '2T476', 'bid': 90, 'type': 'HIGH_CARD'}, {'cards': '2T6Q5', 'bid': 559, 'type': 'HIGH_CARD'}, {'cards': '2Q695', 'bid': 273, 'type': 'HIGH_CARD'}, {'cards': '2K597', 'bid': 742, 'type': 'HIGH_CARD'}, {'cards': '3298A', 'bid': 325, 'type': 'HIGH_CARD'}, {'cards': '3562T', 'bid': 877, 'type': 'HIGH_CARD'}, {'cards': '3769A', 'bid': 429, 'type': 'HIGH_CARD'}, {'cards': '37K2A', 'bid': 348, 'type': 'HIGH_CARD'}, {'cards': '37A25', 'bid': 300, 'type': 'HIGH_CARD'}, {'cards': '382QA', 'bid': 320, 'type': 'HIGH_CARD'}, {'cards': '39K28', 'bid': 665, 'type': 'HIGH_CARD'}, {'cards': '3T549', 'bid': 811, 'type': 'HIGH_CARD'}, {'cards': '469T8', 'bid': 72, 'type': 'HIGH_CARD'}, {'cards': '4732A', 'bid': 420, 'type': 'HIGH_CARD'}, {'cards': '473Q6', 'bid': 988, 'type': 'HIGH_CARD'}, {'cards': '475K6', 'bid': 109, 'type': 'HIGH_CARD'}, {'cards': '4853Q', 'bid': 476, 'type': 'HIGH_CARD'}, {'cards': '4938T', 'bid': 156, 'type': 'HIGH_CARD'}, {'cards': '49586', 'bid': 515, 'type': 'HIGH_CARD'}, {'cards': '4T7A5', 'bid': 956, 'type': 'HIGH_CARD'}, {'cards': '4T9K6', 'bid': 997, 'type': 'HIGH_CARD'}, {'cards': '4K586', 'bid': 760, 'type': 'HIGH_CARD'}, {'cards': '4A2T5', 'bid': 984, 'type': 'HIGH_CARD'}, {'cards': '4A638', 'bid': 880, 'type': 'HIGH_CARD'}, {'cards': '4AK87', 'bid': 78, 'type': 'HIGH_CARD'}, {'cards': '52T67', 'bid': 177, 'type': 'HIGH_CARD'}, {'cards': '53Q8K', 'bid': 257, 'type': 'HIGH_CARD'}, {'cards': '5637T', 'bid': 734, 'type': 'HIGH_CARD'}, {'cards': '57AQ4', 'bid': 671, 'type': 'HIGH_CARD'}, {'cards': '58KA4', 'bid': 795, 'type': 'HIGH_CARD'}, {'cards': '592A6', 'bid': 449, 'type': 'HIGH_CARD'}, {'cards': '59873', 'bid': 555, 'type': 'HIGH_CARD'}, {'cards': '59Q7T', 'bid': 944, 'type': 'HIGH_CARD'}, {'cards': '5T9K4', 'bid': 780, 'type': 'HIGH_CARD'}, {'cards': '5TK47', 'bid': 395, 'type': 'HIGH_CARD'}, {'cards': '5QT27', 'bid': 959, 'type': 'HIGH_CARD'}, {'cards': '5QK4A', 'bid': 474, 'type': 'HIGH_CARD'}, {'cards': '5K6Q2', 'bid': 971, 'type': 'HIGH_CARD'}, {'cards': '5A9KQ', 'bid': 494, 'type': 'HIGH_CARD'}, {'cards': '6347A', 'bid': 497, 'type': 'HIGH_CARD'}, {'cards': '654A9', 'bid': 700, 'type': 'HIGH_CARD'}, {'cards': '687A5', 'bid': 528, 'type': 'HIGH_CARD'}, {'cards': '694T2', 'bid': 679, 'type': 'HIGH_CARD'}, {'cards': '6T789', 'bid': 167, 'type': 'HIGH_CARD'}, {'cards': '6A328', 'bid': 246, 'type': 'HIGH_CARD'}, {'cards': '6A583', 'bid': 814, 'type': 'HIGH_CARD'}, {'cards': '6AT54', 'bid': 79, 'type': 'HIGH_CARD'}, {'cards': '72Q5A', 'bid': 908, 'type': 'HIGH_CARD'}, {'cards': '73A6T', 'bid': 106, 'type': 'HIGH_CARD'}, {'cards': '74K28', 'bid': 523, 'type': 'HIGH_CARD'}, {'cards': '75468', 'bid': 282, 'type': 'HIGH_CARD'}, {'cards': '75496', 'bid': 4, 'type': 'HIGH_CARD'}, {'cards': '754TQ', 'bid': 74, 'type': 'HIGH_CARD'}, {'cards': '75682', 'bid': 960, 'type': 'HIGH_CARD'}, {'cards': '78T2A', 'bid': 112, 'type': 'HIGH_CARD'}, {'cards': '7QK65', 'bid': 716, 'type': 'HIGH_CARD'}, {'cards': '7K523', 'bid': 985, 'type': 'HIGH_CARD'}, {'cards': '7A6Q9', 'bid': 220, 'type': 'HIGH_CARD'}, {'cards': '823A4', 'bid': 457, 'type': 'HIGH_CARD'}, {'cards': '834A9', 'bid': 688, 'type': 'HIGH_CARD'}, {'cards': '84697', 'bid': 581, 'type': 'HIGH_CARD'}, {'cards': '85926', 'bid': 435, 'type': 'HIGH_CARD'}, {'cards': '8692A', 'bid': 844, 'type': 'HIGH_CARD'}, {'cards': '86Q35', 'bid': 764, 'type': 'HIGH_CARD'}, {'cards': '8734Q', 'bid': 538, 'type': 'HIGH_CARD'}, {'cards': '87QAK', 'bid': 970, 'type': 'HIGH_CARD'}, {'cards': '8Q6AT', 'bid': 973, 'type': 'HIGH_CARD'}, {'cards': '8Q756', 'bid': 163, 'type': 'HIGH_CARD'}, {'cards': '8K3AT', 'bid': 934, 'type': 'HIGH_CARD'}, {'cards': '8A294', 'bid': 57, ' ...

# %%
sum = 0
for i in range(len(updated_hands)):
    sum += (i+1) * updated_hands[i]["bid"]

print(sum)
# Out:
# 248747492
